# %%
import numpy as np
import pandas as pd
import yfinance as yf
import requests

# %% [markdown]
# We will be focusing on WTI Crude Oil, and use Brent Crude Oil as a reference.

# %% [markdown]
# Continuous WTI Prices since 2008.5.1 -- present

# %%
wti = yf.download('CL=F', start = '2007-07-01', end = '2025-12-31')
wti.head()
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open  Volume
# Ticker           CL=F       CL=F       CL=F       CL=F    CL=F
# Date
# 2007-07-02  71.089996  71.339996  69.570000  70.519997  217108
# 2007-07-03  71.410004  71.489998  70.699997  71.279999  217108
# 2007-07-05  71.809998  72.349998  70.800003  71.250000  226307
# 2007-07-06  72.809998  72.940002  71.559998  71.800003  219298
# 2007-07-09  72.190002  73.000000  71.809998  72.750000  227743

# %% [markdown]
# Continuous Brent Prices since 2008.5.1 -- Present

# %%
brent = yf.download('BZ=F',start = '2007-07-01', end = '2025-12-31')
brent.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open Volume
# Ticker           BZ=F       BZ=F       BZ=F       BZ=F   BZ=F
# Date
# 2007-07-30  75.739998  76.529999  75.440002  75.849998   2575
# 2007-07-31  77.050003  77.169998  75.669998  75.699997   3513
# 2007-08-01  75.349998  77.059998  74.860001  77.000000   3930
# 2007-08-02  75.760002  76.209999  74.269997  75.220001   6180
# 2007-08-03  74.750000  76.000000  74.529999  75.389999   4387

# %% [markdown]
# US Crude Oil monthly imports quantity from 2009 - 01 to 2024 - 12

# %%
# Define the API URL
url = "https://api.eia.gov/v2/crude-oil-imports/data/?frequency=monthly&data[0]=quantity&start=2009-01&end=2024-12&sort[0][column]=period&sort[0][direction]=desc&sort[1][column]=quantity&sort[1][direction]=asc&offset=0&length=5000"

# Define the API parameters
params = {
    "frequency": "monthly",
    "data": ["quantity"],
    "facets": {},  # Empty facets means all data
    "start": "2009-01",
    "end": "2024-12",
    "sort": [
        {"column": "period", "direction": "desc"},
        {"column": "quantity", "direction": "asc"}
    ],
    "offset": 0,
    "length": 5000  # Maximum number of results
}

# Replace with your EIA API key
api_key = "DyAfRezUNqRWwYfUjsX9crp1UjD9G3EYsj3CCfxJ"

# Send the GET request
headers = {"X-Params": str(params)}
response = requests.get(url, headers=headers, params={"api_key": api_key})

# Check if the request was successful
if response.status_code == 200:
    data = response.json()  # Convert response to JSON
    
    # Extract the 'data' field into a Pandas DataFrame
    if "response" in data and "data" in data["response"]:
        oil_import = pd.DataFrame(data["response"]["data"])
        print("Data successfully retrieved!")
        
        # Display first few rows
        oil_import.head()
    else:
        print("No data found in response.")
else:
    print(f"Error: {response.status_code}, {response.text}")
oil_import.head()
# Out:
# Data successfully retrieved!
#     period originId originName originType originTypeName destinationId  \
# 0  2014-05   CTY_EC    Ecuador        CTY        Country       PT_2017
# 1  2014-05   CTY_EC    Ecuador        CTY        Country       PT_2704
# 2  2014-05   CTY_EC    Ecuador        CTY        Country       PT_2820
# 3  2014-05   CTY_EC    Ecuador        CTY        Country       PT_2830
# 4  2014-05   CTY_EC    Ecuador        CTY        Country       PT_5312
#
#     destinationName destinationType destinationTypeName gradeId    gradeName
# 0  Lake Charles, LA              PT                Port     HSW  Heavy Sweet
# 1   Los Angeles, CA              PT                Port     HSO   Heavy Sour
# 2      Martinez, CA              PT                Port     HSO   Heavy Sour
# 3  Carquinez St, CA              PT                Port     HSO   Heavy Sour
# 4  Corpus Chris, TX              PT                Port     HSO   Heavy Sour

# %% [markdown]
# Crude Oil P

# %%
# Define the API URL
url = "https://api.eia.gov/v2/petroleum/crd/pres/data/?frequency=annual&data[0]=value&start=1899&end=2021&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000"
# Define the API parameters
params = {
    "frequency": "monthly",
    "data": ["quantity"],
    "facets": {},  # Empty facets means all data
    "start": "1899-01",
    "end": "2024-12",
    "sort": [
        {"column": "period", "direction": "desc"},
        {"column": "quantity", "direction": "asc"}
    ],
    "offset": 0,
    "length": 5000  # Maximum number of results
}

# Replace with your EIA API key
api_key = "DyAfRezUNqRWwYfUjsX9crp1UjD9G3EYsj3CCfxJ"

# Send the GET request
headers = {"X-Params": str(params)}
response = requests.get(url, headers=headers, params={"api_key": api_key})

# Check if the request was successful
if response.status_code == 200:
    data = response.json()  # Convert response to JSON
    
    # Extract the 'data' field into a Pandas DataFrame
    if "response" in data and "data" in data["response"]:
        Petroleum = pd.DataFrame(data["response"]["data"])
        print("Data successfully retrieved!")
        
        # Display first few rows
        Petroleum.head()
    else:
        print("No data found in response.")
else:
    print(f"Error: {response.status_code}, {response.text}")
Petroleum.head()
# Out:
# Data successfully retrieved!
#   period duoarea area-name product product-name process     process-name  \
# 0   2002    RUSF        NA    EPC0    Crude Oil     R01  Proved Reserves
# 1   2003    RUSF        NA    EPC0    Crude Oil     R01  Proved Reserves
# 2   2019    RUSF        NA    EPC0    Crude Oil     R01  Proved Reserves
# 3   1987    R44F        NA    EPC0    Crude Oil     R01  Proved Reserves
# 4   1994    R44F        NA    EPC0    Crude Oil     R01  Proved Reserves
#
#          series                                 series-description
# 0  RCRR01R48F_1  U.S. Federal Offshore Crude Oil Proved Reserve...
# 1  RCRR01R48F_1  U.S. Federal Offshore Crude Oil Proved Reserve...
# 2  RCRR01R48F_1  U.S. Federal Offshore Crude Oil Proved Reserve...
# 3  RCRR01R44F_1  Gulf of Mexico Federal Offshore  (Western) Cru...
# 4  RCRR01R44F_1  Gulf of Mexico Federal Offshore  (Western) Cru...

# %% [markdown]
# Track Imports/Eports and Movements -- Weekly Preliminary Crude Imports By Top 10 Countries of Origin - from 2010-6-4 -- Present

# %%
# Define the API URL
url = "https://api.eia.gov/v2/petroleum/move/wimpc/data/?frequency=weekly&data[0]=value&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000"
params = {
    "frequency": "weekly",  # Ensure the frequency matches the dataset
    "data": ["value"],
    "start": "2010-06-04",  # Use a valid start date
    "sort": [
        {"column": "period", "direction": "desc"}
    ],
    "offset": 0,
    "length": 5000  # Maximum number of results
}

# Replace with your EIA API key
api_key = "DyAfRezUNqRWwYfUjsX9crp1UjD9G3EYsj3CCfxJ"

# Send the GET request
headers = {"X-Params": str(params)}
response = requests.get(url, headers=headers, params={"api_key": api_key})

# Check if the request was successful
if response.status_code == 200:
    data = response.json()  # Convert response to JSON
    
    # Print API response to check structure
    print(data)
    
    # Ensure 'response' and 'data' fields exist
    if "response" in data and "data" in data["response"]:
        wklyCrdImprt10org = pd.DataFrame(data["response"]["data"])
        print("Data successfully retrieved!")
    else:
        print("No data found in response.")
        wklyCrdImprt10org = pd.DataFrame()  # Assign an empty DataFrame
else:
    print(f"Error: {response.status_code}, {response.text}")
    wklyCrdImprt10org = pd.DataFrame()  # Assign an empty DataFrame in case of failure

# Display first few rows if data exists
if not wklyCrdImprt10org.empty:
    print(wklyCrdImprt10org.head())
else:
    print("No data to display.")
# Out:
# {'response': {'warnings': [{'warning': 'incomplete return', 'description': 'The API can only return 5000 rows in JSON format.  Please consider constraining your request with facet, start, or end, or using offset to paginate results.'}], 'total': '14133', 'dateFormat': 'YYYY-MM-DD', 'frequency': 'weekly', 'data': [{'period': '2024-07-05', 'duoarea': 'NUS-NAO', 'area-name': 'AGO', 'product': 'EPC0', 'product-name': 'Crude Oil', 'process': 'IM0', 'process-name': 'Imports', 'series': 'W_EPC0_IM0_NUS-NAO_MBBLD', 'series-description': 'U.S. Imports from Angola of Crude Oil (Thousand Barrels per Day)'}, {'period': '2024-06-28', 'duoarea': 'NUS-NAO', 'area-name': 'AGO', 'product': 'EPC0', 'product-name': 'Crude Oil', 'process': 'IM0', 'process-name': 'Imports', 'series': 'W_EPC0_IM0_NUS-NAO_MBBLD', 'series-description': 'U.S. Imports from Angola of Crude Oil (Thousand Barrels per Day)'}, {'period': '2024-02-02', 'duoarea': 'NUS-NAO', 'area-name': 'AGO', 'product': 'EPC0', 'product-name': 'Cr
# ...
